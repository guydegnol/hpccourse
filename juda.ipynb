# %% [markdown]
# # Run cuda C/C++ on jupyter notebook
#
#
# **What is CUDA?**
#
# CUDA is a model created by Nvidia for parallel computing platform and application programming interface. CUDA is the parallel computing architecture of NVIDIA which allows for dramatic increases in computing performance by harnessing the power of the GPU.
#
# **What is Google Colab?**
#
# Google Colab is a free cloud service and the most important feature able to distinguish Colab from other free cloud services is; Colab offers GPU and is completely free! With Colab you can work on the GPU with CUDA C/C++ for free!
# CUDA code will not run on AMD CPU or Intel HD graphics unless you have NVIDIA hardware inside your machine.On Colab you can take advantage of Nvidia GPU as well as being a fully functional Jupyter Notebook with pre-installed Tensorflow and some other ML/DL tools.
#
#
# I guess, I’m done with the introduction. Let’s configure our learning environment.
#
# **Step 1: Go to https://colab.research.google.com in Browser and Click on New Notebook. **
#
# **Step 2: We need to switch our runtime from CPU to GPU. Click on Runtime > Change runtime type > Hardware Accelerator > GPU > Save.**
#
# Execution -> Modifier le type d'execution
#
# **Step 3 (no longer required): Completely uninstall any previous CUDA versions.We need to refresh the Cloud Instance of CUDA.**

# %%
# %%bash
#
# pip install git+https://github.com/guydegnol/hpcgpu_course.git
# pip list | grep hp
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/guydegnol/hpcgpu_course.git to /tmp/pip-req-build-a1fr3vcz
# hpcgpu                        0.1.5
#   Running command git clone -q https://github.com/guydegnol/hpcgpu_course.git /tmp/pip-req-build-a1fr3vcz

# %%
#!pip install git+https://github.com/guydegnol/hpcgpu_course.git
#!pip list | grep hp
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/guydegnol/hpcgpu_course.git to /tmp/pip-req-build-saemcz5t
#   Running command git clone -q https://github.com/guydegnol/hpcgpu_course.git /tmp/pip-req-build-saemcz5t
# ...
#   Created wheel for hpcgpu: filename=hpcgpu-0.1.3-py3-none-any.whl size=4679 sha256=8386c835425667a24ec2530a17a2f1ddf8968276e0a66839edcdbdbc54acdc7b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7wqfilr7/wheels/4f/68/47/ec0a4437162553a6f3badaab939cdcfaab89c2a07c45404267
# Successfully built hpcgpu
# ...
#   Attempting uninstall: hpcgpu
#     Found existing installation: hpcgpu 0.1.2
#     Uninstalling hpcgpu-0.1.2:
#       Successfully uninstalled hpcgpu-0.1.2
# ...
# hpcgpu                        0.1.3

# %%
#import hpcourse
#import hpcourse3
#import v1
#import nvcc
#print(dir(hpcourse))
#hpcourse.hpcourse3.get_p3()
#hpcourse#.get_p2()
#v1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-94818f7f6503> in <module>
#       7 #hpcourse#.get_p2()
#       8 #v1
# ----> 9 hpcourse.__version__
#
# AttributeError: module 'hpcourse' has no attribute '__version__'

# %%
# %%bash
#
# #!apt-get --purge remove cuda nvidia* libnvidia-*
# #!dpkg -l | grep cuda- | awk '{print $2}' | xargs -n1 dpkg --purge
# #!apt-get remove cuda-*
# #!apt autoremove
# #!apt-get update

# %% [markdown]
# Write code in a separate code Block and Run that code.Every line that starts with ‘!’, it will be executed as a command line command.
#
#
#
# **Step 4 (no longer required): Install CUDA Version 9 (You can just copy it in separate code block).**

# %%
# !dpkg -l | grep cuda
# Out:
# iU  cuda-9-2                               9.2.88-1                            amd64        CUDA 9.2 meta-package
# iU  cuda-command-line-tools-9-2            9.2.88-1                            amd64        CUDA command-line tools
# iU  cuda-compiler-9-2                      9.2.88-1                            amd64        CUDA compiler
# iU  cuda-cublas-9-2                        9.2.88-1                            amd64        CUBLAS native runtime libraries
# iU  cuda-cublas-dev-9-2                    9.2.88-1                            amd64        CUBLAS native dev links, headers
# rc  cuda-cudart-11-2                       11.2.152-1                          amd64        CUDA Runtime native Libraries
# iU  cuda-cudart-9-2                        9.2.88-1                            amd64        CUDA Runtime native Libraries
# iU  cuda-cudart-dev-9-2                    9.2.88-1                            amd64        CUDA Runtime native dev links, headers
# ...

# %%
wget https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64/cuda-keyring_1.0-1_all.deb
sudo dpkg -i cuda-keyring_1.0-1_all.deb
sudo apt-get update
sudo apt-get -y install cuda

# %%
# !wget https://developer.nvidia.com/compute/cuda/9.2/Prod/local_installers/cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64 -O cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64.deb
# !dpkg -i cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64.deb
# !apt-key add /var/cuda-repo-9-2-local/7fa2af80.pub
# !apt-get update
# !apt-get install cuda-9.2
# Out:
# --2022-10-20 09:23:41--  https://developer.nvidia.com/compute/cuda/9.2/Prod/local_installers/cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64
# Resolving developer.nvidia.com (developer.nvidia.com)... 152.199.39.144
# Connecting to developer.nvidia.com (developer.nvidia.com)|152.199.39.144|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://developer.nvidia.com/compute/cuda/9.2/prod/local_installers/cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64 [following]
# --2022-10-20 09:23:43--  https://developer.nvidia.com/compute/cuda/9.2/prod/local_installers/cuda-repo-ubuntu1604-9-2-local_9.2.88-1_amd64
# Reusing existing connection to developer.nvidia.com:443.
# HTTP request sent, awaiting response... 302 Found
# ...

# %% [markdown]
# **Step 5: Now you can check your CUDA installation by running the command given below :**

# %%
# %%bash
#
# apt-get install -qq cuda gcc-5 g++-5 -y
# ln -s /usr/bin/gcc-5 /usr/local/cuda/bin/gcc
# ln -s /usr/bin/g++-5 /usr/local/cuda/bin/g++
# /usr/local/cuda/bin/nvcc --version
# Out:
# E: Unmet dependencies. Try 'apt --fix-broken install' with no packages (or specify a solution).
# ln: failed to create symbolic link '/usr/local/cuda/bin/gcc': No such file or directory
# ln: failed to create symbolic link '/usr/local/cuda/bin/g++': No such file or directory
# bash: line 5: /usr/local/cuda/bin/nvcc: No such file or directory
# bash: line 8: nvcc: command not found
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-10-ccf9c004d35e> in <module>
# ----> 1 get_ipython().run_cell_magic('bash', '', '\napt-get install -qq cuda gcc-5 g++-5 -y\nln -s /usr/bin/gcc-5 /usr/local/cuda/bin/gcc\nln -s /usr/bin/g++-5 /usr/local/cuda/bin/g++\n/usr/local/cuda/bin/nvcc --version\n\n\nnvcc --version\n')
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
# ...

# %% [markdown]
# **Step 6: Run the given command to install a small extension to run nvcc from the Notebook cells.**

# %%
# !pip install git+https://github.com/guydegnol/hpcgpu_course.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/guydegnol/hpcgpu_course.git to /tmp/pip-req-build-rhpfy65c
#   Running command git clone -q https://github.com/guydegnol/hpcgpu_course.git /tmp/pip-req-build-rhpfy65c
# ...
#   Created wheel for NVCCPlugin: filename=NVCCPlugin-0.0.2-py3-none-any.whl size=4306 sha256=cff46c73d65012876dd92cf9d981f13650c8ad4754ff498acc64e6477f17eb5d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-y_d82e5s/wheels/4f/68/47/ec0a4437162553a6f3badaab939cdcfaab89c2a07c45404267
# Successfully built NVCCPlugin
# ...

# %% [markdown]
# **Step 7: Load the extension using the code given below:**

# %%
# %load_ext nvcc_plugin
# Out:
# The nvcc_plugin extension is already loaded. To reload it, use:
#   %reload_ext nvcc_plugin

# %% [markdown]
# **Step 8: Execute the code given below to check if CUDA is working or not.**
#
# Now we are ready to run CUDA C/C++ code right in your Notebook.
#
#
# *Important Note: To check the following code is working or not, write that code in a separate code block and Run that only again when you update the code and re running it.*
#
# To run the code in your notebook, add the %%cu extension at the beginning of your code.

# %%
# %%cuda
# #include <iostream>
# int main()
# {
#     std::cout << "Welcome To GeeksforGeeks\n";
#     return 0;
# }
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-9931701bbb63> in <module>
# ----> 1 get_ipython().run_cell_magic('cuda', '', '#include <iostream>\nint main()\n{\n    std::cout << "Welcome To GeeksforGeeks\\n";\n    return 0;\n}\n')
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2357             with self.builtin_trap:
#    2358                 args = (magic_arg_s, cell)
# -> 2359                 result = fn(*args, **kwargs)
#    2360             return result
#    2361
#
# <decorator-gen-119> in cuda(self, line, cell)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
# ...

# %% [markdown]
# I suggests you to try program of find maximum element from vector to check that everything works properly.

# %%
# %%cu
# #include <cstdio>
# #include <iostream>
#
#     using namespace std;
#
# __global__ void maxi(int* a, int* b, int n)
# {
#     int block = 256 * blockIdx.x;
#     int max = 0;
#
#     for (int i = block; i < min(256 + block, n); i++) {
#
#         if (max < a[i]) {
#             max = a[i];
#         }
#     }
#     b[blockIdx.x] = max;
# }
#
# int main()
# {
#
#     int n;
#     n = 3 >> 2;
#     int a[n];
#
#     for (int i = 0; i < n; i++) {
#         a[i] = rand() % n;
#         cout << a[i] << "\t";
#     }
#
#     cudaEvent_t start, end;
#     int *ad, *bd;
#     int size = n * sizeof(int);
#     cudaMalloc(&ad, size);
#     cudaMemcpy(ad, a, size, cudaMemcpyHostToDevice);
#     int grids = ceil(n * 1.0f / 256.0f);
#     cudaMalloc(&bd, grids * sizeof(int));
#
#     dim3 grid(grids, 1);
#     dim3 block(1, 1);
#
#     cudaEventCreate(&start);
#     cudaEventCreate(&end);
#     cudaEventRecord(start);
#
#     while (n > 1) {
#         maxi<<<grids, block>>>(ad, bd, n);
#         n = ceil(n * 1.0f / 256.0f);
#         cudaMemcpy(ad, bd, n * sizeof(int), cudaMemcpyDeviceToDevice);
#     }
#
#     cudaEventRecord(end);
#     cudaEventSynchronize(end);
#
#     float time = 0;
#     cudaEventElapsedTime(&time, start, end);
#
#     int ans[2];
#     cudaMemcpy(ans, ad, 4, cudaMemcpyDeviceToHost);
#
#     cout << "The maximum element is : " << ans[0] << endl;
#
#     cout << "The time required : ";
#     cout << time << endl;
# }
# Out:
# UsageError: Cell magic `%%cu` not found.
